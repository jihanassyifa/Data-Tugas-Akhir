# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams['font.family'] = 'STIXGeneral'
plt.rcParams.update({'font.size': 20})

df = pd.read_csv("D:\SATELITLAPAN_A1.txt", sep="\s+", header=None,
                  names=["No Katalog Satelit", "Epoch", "B*", "True Anomaly", "Height"])

df
# Out:
#       No Katalog Satelit        Epoch        B*  True Anomaly      Height
# 0                  29709  2023.000649  0.000088     20.543896  612.714429
# 1                  29709  2023.001758  0.000090     21.878447  612.848845
# 2                  29709  2023.002868  0.000092     23.256904  612.933803
# 3                  29709  2023.003792  0.000096     24.259188  612.972394
# 4                  29709  2023.005086  0.000095     26.093809  613.155516
# ...                  ...          ...       ...           ...         ...
# 1985               29709  2024.407641  0.000106    258.614464  618.715748
# 1986               29709  2024.408378  0.000103    259.401278  618.582951
# 1987               29709  2024.408562  0.000113    259.605375  618.546675
# 1988               29709  2024.409483  0.000128    260.596555  618.375692
# 1989               29709  2024.409668  0.000129    260.790257  618.342522
#
# [1990 rows x 5 columns]

# %%
df['Epoch']
# Out:
# 0       2023.000649
# 1       2023.001758
# 2       2023.002868
# 3       2023.003792
# 4       2023.005086
#            ...
# 1985    2024.407641
# 1986    2024.408378
# 1987    2024.408562
# 1988    2024.409483
# 1989    2024.409668
# Name: Epoch, Length: 1990, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(19,6.5))
plt.title("Epoch Terhadap Parameter B* Satelit LAPAN-A1", fontsize=25)
plt.plot(df["Epoch"], df['B*'], color='black', linewidth=1.5)
plt.xlabel("Epoch (year)", fontsize=17)
plt.ylabel("Hambatan Atmosfer (B*)", fontsize=17)
plt.grid()
ax.text(0.01, 0.95, '(b)', horizontalalignment='left', verticalalignment='top', fontsize=20, transform=ax.transAxes)

plt.show()
